# %%
# %run Archpool.ipynb
# %run Argparser.ipynb
# %run Topo_treatment.ipynb
# %run Net.ipynb

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.utils import save_image

import model
from dataset import *
from utils import check_dir
from tqdm import tqdm
import numpy as np
from functools import reduce

import os
import json
import argparse

import sys
import json
sys.path.insert(0, './persis_lib_cpp')
from persis_homo_optimal import *

torch_device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


def parse_args():
    '''parser = argparse.ArgumentParser()
    parser.add_argument('config', help='configuration file path')
    opt = parser.parse_args()
    with open(opt.config, 'r') as inf:
        config = json.load(inf)'''
    
    f = open('example.json')
    config = json.load(f)

    try:
        if config['output_path'][-1] != '/':
            config['output_path'] += '/'
        if config['train_data_path'][-1] != '/':
            config['train_data_path'] += '/'
        if config['val_data_path'][-1] != '/':
            config['val_data_path'] += '/'
    except KeyError as err:
        print(f'{opt.config}: Unspecified path {err}')
        exit(1)
    return config


def initialize_network(config):
    network = {}
    random_seed = 0
    try:
        config['resume']
        random_seed = config['random_seed']
    except KeyError:
        config['resume'] = False
    torch.manual_seed(random_seed)
    if (config['resume'] and os.path.isfile(config['resume'])):
        confout = config['output_path'] + config['name'] + '/'
        network['resume'] = True
        checkpoint = torch.load(config['resume'], map_location=torch_device)
        network['epoch_start'] = checkpoint['epoch'] + \
            1 if checkpoint['output_dir'] == confout else 0
        network['epoch_end'] = config['epoch'] or checkpoint['epoch_end']
        network['output_dir'] = confout
        network['checkpoint_dir'] = checkpoint['checkpoint_dir']
        network['learning_rate'] = checkpoint['learning_rate']
        network['train_data_dir'] = checkpoint['train_data_dir']
        network['val_data_dir'] = checkpoint['val_data_dir']
        network['name'] = checkpoint['name']
        network['batch_size'] = checkpoint['batch_size']
        network['features'] = checkpoint['features']
        network['image_size'] = checkpoint['image_size']
        network['image_channels'] = checkpoint['image_channels']
        network['optimizer_name'] = checkpoint['optimizer_name']
        network['arch'] = checkpoint['arch']
        network['bn'] = checkpoint['bn']
        network['checkpoint'] = checkpoint
    else:
        network['resume'] = False
        try:
            network['output_dir'] = config['output_path'] + \
                config['name'] + '/'
            network['name'] = config['name']
            network['epoch_start'] = 0
            network['epoch_end'] = config['epoch']
            network['learning_rate'] = config['learning_rate']
            network['batch_size'] = config['batch_size']
            network['features'] = int(config['features'])
            network['image_size'] = config['image_size']
            network['image_channels'] = config['image_channels']
            network['optimizer_name'] = config['optimizer']
            network['train_data_dir'] = config['train_data_path']
            network['val_data_dir'] = config['val_data_path']
            network['arch'] = config['arch']
            network['bn'] = config['bn']
        except KeyError as err:
            print(f'Configuration: Unspecified field {err}')
            exit(1)
    network['checkpoint_dir'] = network['output_dir'] + 'checkpoints/'
    network['result_dir'] = network['output_dir'] + 'result/'
    check_dir(network['output_dir'])
    check_dir(network['checkpoint_dir'])
    check_dir(network['result_dir'])

    network['logfile_path'] = network['result_dir'] + 'logfile.txt'
    network['performance_path'] = network['result_dir'] + 'performance.txt'
    learning_model = model.AutoEncoder(
        network['image_size'], network['image_channels'], network['features'], network['arch'], network['bn'])
    #learning_model.load_state_dict(torch.load("C:/Users/nelsite/Desktop/Coding_with_Fahim/Topological_Segmentation/TopoSegNetSimple/network/Output/Unet_Training/checkpoints/Unet_Training_49.pth"))
    learning_model = learning_model.to(torch_device)
    
    network['loss_function'] = WeightedBCELoss(one_weight=1,zeros_weight=1)
    # network['loss_function'] = nn.MSELoss()
    optimizer = None
    if network['optimizer_name'] == 'adam':
        optimizer = optim.Adam(learning_model.parameters(),
                               lr=network['learning_rate'])
    elif network['optimizer_name'] == 'sgd':
        optimizer = optim.SGD(learning_model.parameters(),
                              momentum=0.9, weight_decay=1e-2,
                              lr=network['learning_rate'])

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5, patience=1)

    if (network['resume']):
        learning_model.load_state_dict(network['checkpoint']['model'])
        optimizer.load_state_dict(network['checkpoint']['optimizer'])
        scheduler.load_state_dict(network['checkpoint']['scheduler'])
    
    network['model'] = learning_model
    network['optimizer'] = optimizer
    network['scheduler'] = scheduler
    return network


class WeightedBCELoss:
    def __init__(self, one_weight=1.0, zeros_weight=1.0, reduction="mean"):
        self.reduction = reduction
        self.update_weights(one_weight, zeros_weight)

    def update_weights(self, one_weight, zeros_weight):
        self.weights = torch.FloatTensor([one_weight, zeros_weight])
        self.weights.to(torch_device)

    def _bce(self, x, y):
        weights = -self.weights
        x = torch.clamp(x, min=1e-7, max=1-1e-7)
        y = torch.clamp(y, min=1e-7, max=1-1e-7)
        return weights[1]*y*torch.log(x) + weights[0]*(1-y)*torch.log(1-x)

    def __call__(self, pred, truth):
        loss = self._bce(pred, truth)
        if self.reduction == 'mean':
            return torch.mean(loss)
        if self.reduction == 'sum':
            return torch.sum(loss)
        return loss



def train(adv_params, network, dataloader, withTopo=True):
    
    et = Edges_(adv_params, debug=False)
    #criterionT = GANLoss("vanilla_topo", "sum").to(torch_device)
    criterionT = nn.BCEWithLogitsLoss(reduction="sum")
    loss_function = network['loss_function']
    model = network['model']
    optimizer = network['optimizer']
    model.train()
    running_loss = 0.0
    t_loss = 0.0
    alpha = 0.96
    result_dir = network['result_dir']
    batch_number = 0
    step_num = 0
    tot_append_loss = 0.0
    for data in dataloader:
        
        step_num = step_num + 1
        print("step_num : ", step_num)
        scalars, label = data

        scalars = scalars.to(torch_device)
        label = label.to(torch_device)
        optimizer.zero_grad()

        p = model(scalars)
        prediction = (p - torch.min(p))/(torch.max(p) - torch.min(p)) *2-1
        
        loss = loss_function(prediction, label)
        running_loss += loss.item()
        print("training loss : ", loss.item())
        
        #loss.backward()
        num_rows = p.size(0)
        s = scalars.cpu().view(
            num_rows, 1, 64, 64).double()
        t = label.cpu().view(
            num_rows, 1, 64, 64).double()

        pred = prediction.cpu().view(
            num_rows, 1, 64, 64).double()
        
        pl = label.cpu().view(
            num_rows, 1, 64, 64).double()
        
        out_image = torch.transpose(torch.stack((s, t, pl,pred)), 0, 1).reshape(
            4*num_rows, 1,  64, 64)
        save_image(out_image.cpu(
        ), f"{result_dir}_batch{batch_number}.png", padding=4, nrow=24)
        batch_number += 1
        
        if withTopo:
            
            tp_wgt   = et.return_tp_weight()
            fake_fix, mean_wasdis = et.fix_with_topo(prediction.detach().cpu().numpy(), label.detach().cpu().numpy(),
                                                     et.return_target_dim(), result_dir, batch_number, num_rows, 
                                                     -1.0, 1.0, blind=et.blind())
            #print( prediction.detach().cpu().numpy().shape, et.return_target_dim())
            fake_fix = torch.from_numpy(fake_fix).to(torch_device)
            
            fake_fix = torch.unsqueeze(fake_fix, 1)
            fake_fix = (fake_fix - torch.min(fake_fix))/(torch.max(fake_fix) - torch.min(fake_fix))
            errT = criterionT(p, fake_fix) * tp_wgt
            t_loss += errT.item()
            print("Topo loss : ", errT.item())
            #errT.backward()
            #total_loss = (alpha * loss) + ((1-alpha) * errT)
            tot_loss = loss + errT
            tot_append_loss += tot_loss.item()
            print("Total loss : ", tot_loss.item())
            tot_loss.backward()
            optimizer.step()
        
        else:
            #loss.backward()
            optimizer.step()
    
    training_loss = running_loss / len(dataloader.dataset)
    topo_loss = t_loss / len(dataloader.dataset)
    total_loss = tot_append_loss / len(dataloader.dataset)
    
    return [training_loss], [topo_loss], [total_loss]


def validate(network, dataloader, epoch):
    image_size = [network['image_size'], network['image_size']]
    running_loss = 0.0
    tp = 0.0  # true positive
    tn = 0.0  # true negative
    fp = 0.0  # false positive
    fn = 0.0  # false negative

    l1_diff = 0.0
    with torch.no_grad():
        loss_function = network['loss_function']
        model = network['model']
        result_dir = network['result_dir']
        image_channels = network['image_channels']
        model.eval()
        batch_number = 0
        output_image = False
        for i, data in enumerate(dataloader):
            scalars, label = data
            label = label.to(torch_device)
            scalars = scalars.to(torch_device)
            batch_size = label.size(0)

            prediction = model(scalars)
            '''pred = prediction.cpu().detach().numpy()
            pred = np.squeeze(pred)
            fig, ax = plt.subplots(nrows=1, ncols=5, figsize=(12, 4))
            for i in range(5):
                ax[i].imshow(pred[i], cmap='gray')
                ax[i].axis('off')

            plt.show()'''
            
            loss = loss_function(prediction, label)
            running_loss += loss.item() * batch_size
            # log accuracy
            pred = prediction.cpu().view(batch_size, -1).double()
            truth = label.cpu().view(batch_size, -1).double()

            plabel = torch.zeros(pred.size())
            plabel[pred >= 0.3] = 1
            tp += torch.sum(torch.logical_and(plabel == 1, truth == 1).float())
            tn += torch.sum(torch.logical_and(plabel == 0, truth == 0).float())
            fp += torch.sum(torch.logical_and(plabel == 1, truth == 0).float())
            fn += torch.sum(torch.logical_and(plabel == 0, truth == 1).float())

            l1_diff += torch.sum(torch.abs(pred - truth))

            if epoch != "":
                if (epoch == network['epoch_end'] - 1) or (i == len(dataloader) - 1):
                    output_image = True

            #if output_image:
            num_rows = batch_size
            s = scalars.cpu().view(
                num_rows, 1, image_size[1], image_size[0]).double()
            t = label.cpu().view(
                num_rows, 1, image_size[1], image_size[0]).double()

            pred = prediction.cpu().view(
                num_rows, 1, image_size[1], image_size[0]).double()
            
            pl = plabel.cpu().view(
                num_rows, 1, image_size[1], image_size[0]).double()
            
            out_image = torch.transpose(torch.stack((s, t, pl,pred)), 0, 1).reshape(
                4*num_rows, 1,  image_size[1], image_size[0])
            save_image(out_image.cpu(
            ), f"{result_dir}epoch_{epoch}_batch{batch_number}.png", padding=4, nrow=24)
            batch_number += 1
        # end for loop
    # end with nograd
    val_loss = running_loss/len(dataloader.dataset)
    l1_diff /= len(dataloader.dataset)
    tp /= len(dataloader.dataset)
    tn /= len(dataloader.dataset)
    fp /= len(dataloader.dataset)
    fn /= len(dataloader.dataset)
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    precision = (tp)/(tp+fp)
    recall = (tp)/(tp+fn)
    f1 = 2*tp / (2 * tp + fp + fn)

    return [val_loss], [accuracy, precision, recall, f1, l1_diff]


def floats2str(l):
    return ",".join(map(lambda x: f'{x:.6f}', l))


def parameters_count(model):
    total = 0
    total_t = 0
    for p in model.parameters():
        if p.requires_grad:
            total += p.numel()
            total_t += p.numel()
        else:
            total += p.numel()
    return total, total_t


def main():
    adv_params  = return_advanced_params()
    config = parse_args()
    network = initialize_network(config)

    p, pt = parameters_count(network['model'])
    print(f'number of parameters(trainable) {p}({pt})')

    with open(network['output_dir']+'config.json', 'w') as jsonout:
        json.dump(config, jsonout, indent=2)

    train_dataset = ImageBoundary(
        config['train_data_path'], network['image_channels'])
    #i,t = train_dataset[0]
    #print(i,t)
    train_dataloader = DataLoader(
        train_dataset, batch_size=network['batch_size'], shuffle=True)
    val_dataset = ImageBoundary(
        config['val_data_path'], network['image_channels'])
    val_dataloader = DataLoader(
        val_dataset, batch_size=network['batch_size'], shuffle=False)

    '''if network['resume']:
        logfile = open(network['logfile_path'], 'a')
        perf_log = open(network['performance_path'], 'a')
    else:'''
    logfile = open(network['logfile_path'], 'w')
    logfile.write('epoch,train_loss,val_loss,topo_loss,total_loss\n')
    perf_log = open(network['performance_path'], 'w')
    perf_log.write(
        'epoch, accuracy, precision, recall, f1, l1_diff_per_image)\n')

    for epoch in tqdm(range(network['epoch_start'], network['epoch_end'])):
        t_loss, topo_loss, total_loss = train(adv_params, network, train_dataloader, True)
        v_loss, performance = validate(network, val_dataloader, epoch)
        network['scheduler'].step(total_loss[0])

        performance = floats2str(performance)
        perf_log.write(f'{epoch},{performance}\n')
        perf_log.flush()

        t_loss = floats2str(t_loss)
        v_loss = floats2str(v_loss)
        topo_loss = floats2str(topo_loss)
        total_loss = floats2str(total_loss)
        
        logfile.write(f'{epoch},{t_loss},{v_loss},{topo_loss},{total_loss}\n')
        logfile.flush()
        if ((epoch+1) % 50 == 0) or epoch == network['epoch_end'] - 1:
            torch.save({
                'epoch': epoch,
                'epoch_end': network['epoch_end'],
                'model': network['model'].state_dict(),
                'optimizer': network['optimizer'].state_dict(),
                'optimizer_name': network['optimizer_name'],
                'scheduler': network['scheduler'].state_dict(),
                'checkpoint_dir': network['checkpoint_dir'],
                'train_data_dir': network['train_data_dir'],
                'val_data_dir': network['val_data_dir'],
                'output_dir': network['output_dir'],
                'name': network['name'],
                'batch_size': network['batch_size'],
                'learning_rate': network['learning_rate'],
                'features': network['features'],
                'image_size': network['image_size'],
                'image_channels': network['image_channels'],
                'arch': network['arch'],
                'bn': network['bn']
            }, f'{network["checkpoint_dir"]}{network["name"]}_{epoch}.pth')
    logfile.close()
    perf_log.close()


if __name__ == '__main__':
    main()
# Out:
# number of parameters(trainable) 7762465(7762465)
#   0%|                                                                                           | 0/30 [00:00<?, ?it/s]
# step_num :  1
# Average training loss :  0.12208180129528046
# C:\ProgramData\Anaconda3\envs\topo_gan\lib\site-packages\ipykernel_launcher.py:504: DeprecationWarning: Call to deprecated class PersImage. (Replaced with the class `persim.PersistenceImager`.) -- Deprecated since version 0.1.5.
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7073094844818115
# Batchwise Total loss :  2.8293912410736084
# step_num :  2
# Average training loss :  0.12944309413433075
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6969144344329834
# Batchwise Total loss :  2.82635760307312
# step_num :  3
# Average training loss :  0.07764953374862671
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7066917419433594
# Batchwise Total loss :  2.784341335296631
# step_num :  4
# Average training loss :  0.0717177763581276
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.681774616241455
# Batchwise Total loss :  2.7534923553466797
# step_num :  5
# Average training loss :  0.08756354451179504
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6873252391815186
# Batchwise Total loss :  2.774888753890991
# step_num :  6
# Average training loss :  0.07733524590730667
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6977272033691406
# Batchwise Total loss :  2.7750625610351562
# step_num :  7
# Average training loss :  0.09778757393360138
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.677917957305908
# Batchwise Total loss :  2.775705575942993
# step_num :  8
# Average training loss :  0.11750732362270355
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6925041675567627
# Batchwise Total loss :  2.810011386871338
# step_num :  9
# Average training loss :  0.13358363509178162
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6712429523468018
# Batchwise Total loss :  2.804826498031616
# step_num :  10
# Average training loss :  0.1876528561115265
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.677623748779297
# Batchwise Total loss :  2.865276575088501
# step_num :  11
# Average training loss :  0.231400728225708
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.670656681060791
# Batchwise Total loss :  2.902057409286499
# step_num :  12
# Average training loss :  0.2405528724193573
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6774775981903076
# Batchwise Total loss :  2.9180305004119873
# step_num :  13
# Average training loss :  0.17131149768829346
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.699679136276245
# Batchwise Total loss :  2.870990753173828
# step_num :  14
# Average training loss :  0.23961153626441956
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7027199268341064
# Batchwise Total loss :  2.942331552505493
# step_num :  15
# Average training loss :  0.371120423078537
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6810436248779297
# Batchwise Total loss :  3.052164077758789
# step_num :  16
# Average training loss :  0.36609020829200745
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7029924392700195
# Batchwise Total loss :  3.069082736968994
# step_num :  17
# Average training loss :  0.3631512522697449
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6962859630584717
# Batchwise Total loss :  3.0594372749328613
# step_num :  18
# Average training loss :  0.3325323760509491
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.724168539047241
# Batchwise Total loss :  3.0567009449005127
# step_num :  19
# Average training loss :  0.4127996861934662
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7027523517608643
# Batchwise Total loss :  3.1155519485473633
# step_num :  20
# Average training loss :  0.42271384596824646
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7049195766448975
# Batchwise Total loss :  3.1276333332061768
# step_num :  21
# Average training loss :  0.4494001269340515
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.710653305053711
# Batchwise Total loss :  3.1600534915924072
# step_num :  22
# Average training loss :  0.46530500054359436
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7210869789123535
# Batchwise Total loss :  3.186392068862915
# step_num :  23
# Average training loss :  0.4844447672367096
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7261874675750732
# Batchwise Total loss :  3.21063232421875
# step_num :  24
# Average training loss :  0.5536691546440125
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.712857961654663
# Batchwise Total loss :  3.2665271759033203
# step_num :  25
# Average training loss :  0.4897618293762207
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.720254898071289
# Batchwise Total loss :  3.2100167274475098
# step_num :  26
# Average training loss :  0.6119831800460815
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7161848545074463
# Batchwise Total loss :  3.3281679153442383
# step_num :  27
# Average training loss :  0.460183322429657
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.722971200942993
# Batchwise Total loss :  3.183154582977295
# step_num :  28
# Average training loss :  0.6975224018096924
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.725600004196167
# Batchwise Total loss :  3.4231224060058594
# step_num :  29
# Average training loss :  0.6967517137527466
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.742572069168091
# Batchwise Total loss :  3.439323902130127
# step_num :  30
# Average training loss :  0.7482684850692749
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7484443187713623
# Batchwise Total loss :  3.4967126846313477
# step_num :  31
# Average training loss :  0.695467472076416
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.737853765487671
# Batchwise Total loss :  3.433321237564087
# step_num :  32
# Average training loss :  0.8198329210281372
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7348947525024414
# Batchwise Total loss :  3.554727554321289
# step_num :  33
# Average training loss :  0.8546615839004517
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.752331018447876
# Batchwise Total loss :  3.606992721557617
# step_num :  34
# Average training loss :  0.7723404169082642
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.764191150665283
# Batchwise Total loss :  3.536531448364258
# step_num :  35
# Average training loss :  0.8756650686264038
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7452685832977295
# Batchwise Total loss :  3.6209335327148438
# step_num :  36
# Average training loss :  0.9465150833129883
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7471046447753906
# Batchwise Total loss :  3.693619728088379
# step_num :  37
# Average training loss :  0.929202675819397
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.746429681777954
# Batchwise Total loss :  3.6756324768066406
# step_num :  38
# Average training loss :  0.9801963567733765
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.72762393951416
# Batchwise Total loss :  3.707820415496826
# step_num :  39
# Average training loss :  1.0312551259994507
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.734006404876709
# Batchwise Total loss :  3.765261650085449
# step_num :  40
# Average training loss :  0.9782007336616516
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7457287311553955
# Batchwise Total loss :  3.7239294052124023
# step_num :  41
# Average training loss :  0.9737117886543274
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7505085468292236
# Batchwise Total loss :  3.7242202758789062
# step_num :  42
# Average training loss :  0.9992782473564148
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.722223997116089
# Batchwise Total loss :  3.7215023040771484
# step_num :  43
# Average training loss :  1.03413987159729
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.736475706100464
# Batchwise Total loss :  3.770615577697754
# step_num :  44
# Average training loss :  0.93473881483078
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.743990898132324
# Batchwise Total loss :  3.678729772567749
# step_num :  45
# Average training loss :  0.9091348648071289
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.750908613204956
# Batchwise Total loss :  3.660043478012085
# step_num :  46
# Average training loss :  0.9403250813484192
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7368900775909424
# Batchwise Total loss :  3.677215099334717
# step_num :  47
# Average training loss :  1.053112506866455
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7206838130950928
# Batchwise Total loss :  3.773796319961548
# step_num :  48
# Average training loss :  0.8773443102836609
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.736638307571411
# Batchwise Total loss :  3.613982677459717
# step_num :  49
# Average training loss :  0.9691108465194702
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.743525266647339
# Batchwise Total loss :  3.7126359939575195
# step_num :  50
# Average training loss :  0.8928123712539673
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.724872350692749
# Batchwise Total loss :  3.617684841156006
# step_num :  51
# Average training loss :  0.8883548974990845
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.737081527709961
# Batchwise Total loss :  3.625436305999756
# step_num :  52
# Average training loss :  0.9226067662239075
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.722562789916992
# Batchwise Total loss :  3.645169496536255
# step_num :  53
# Average training loss :  1.0112155675888062
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7403781414031982
# Batchwise Total loss :  3.751593589782715
# step_num :  54
# Average training loss :  1.103679895401001
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.731405258178711
# Batchwise Total loss :  3.835085153579712
# step_num :  55
# Average training loss :  0.9289956092834473
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7200446128845215
# Batchwise Total loss :  3.6490402221679688
# step_num :  56
# Average training loss :  0.8570405840873718
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.71506404876709
# Batchwise Total loss :  3.5721046924591064
# step_num :  57
# Average training loss :  0.8028090596199036
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7000691890716553
# Batchwise Total loss :  3.502878189086914
# step_num :  58
# Average training loss :  0.8180146217346191
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7068209648132324
# Batchwise Total loss :  3.5248355865478516
# step_num :  59
# Average training loss :  0.837321937084198
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7193124294281006
# Batchwise Total loss :  3.5566344261169434
# step_num :  60
# Average training loss :  0.8829100728034973
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.704106569290161
# Batchwise Total loss :  3.5870165824890137
# step_num :  61
# Average training loss :  0.9781230688095093
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6922824382781982
# Batchwise Total loss :  3.670405387878418
# step_num :  62
# Average training loss :  0.8285977244377136
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.676748275756836
# Batchwise Total loss :  3.5053460597991943
# step_num :  63
# Average training loss :  0.9486278295516968
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.678358316421509
# Batchwise Total loss :  3.626986026763916
# step_num :  64
# Average training loss :  0.9256560206413269
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6766459941864014
# Batchwise Total loss :  3.602302074432373
# step_num :  65
# Average training loss :  0.9414135217666626
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6845622062683105
# Batchwise Total loss :  3.6259756088256836
# step_num :  66
# Average training loss :  0.9180440902709961
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.658186197280884
# Batchwise Total loss :  3.57623028755188
# step_num :  67
# Average training loss :  0.9476305842399597
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6845602989196777
# Batchwise Total loss :  3.6321909427642822
# step_num :  68
# Average training loss :  0.8920624852180481
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6861703395843506
# Batchwise Total loss :  3.578232765197754
# step_num :  69
# Average training loss :  1.0096582174301147
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6620469093322754
# Batchwise Total loss :  3.6717052459716797
# step_num :  70
# Average training loss :  0.9116852879524231
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6936726570129395
# Batchwise Total loss :  3.6053578853607178
# step_num :  71
# Average training loss :  0.9782177209854126
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.68666672706604
# Batchwise Total loss :  3.664884567260742
# step_num :  72
# Average training loss :  0.8169046640396118
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6965484619140625
# Batchwise Total loss :  3.5134530067443848
# step_num :  73
# Average training loss :  0.946014404296875
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.710120916366577
# Batchwise Total loss :  3.656135320663452
# step_num :  74
# Average training loss :  0.9116552472114563
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7221310138702393
# Batchwise Total loss :  3.633786201477051
# step_num :  75
# Average training loss :  0.8370622396469116
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6976211071014404
# Batchwise Total loss :  3.5346832275390625
# step_num :  76
# Average training loss :  0.9087578654289246
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7348148822784424
# Batchwise Total loss :  3.6435728073120117
# step_num :  77
# Average training loss :  0.9329932928085327
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7474615573883057
# Batchwise Total loss :  3.680454730987549
# step_num :  78
# Average training loss :  1.014158010482788
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7407617568969727
# Batchwise Total loss :  3.7549197673797607
# step_num :  79
# Average training loss :  1.0217111110687256
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7422547340393066
# Batchwise Total loss :  3.7639658451080322
# step_num :  80
# Average training loss :  0.9795308113098145
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7364022731781006
# Batchwise Total loss :  3.715933084487915
# step_num :  81
# Average training loss :  0.9490371942520142
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.779536008834839
# Batchwise Total loss :  3.7285733222961426
# step_num :  82
# Average training loss :  1.000205397605896
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7904889583587646
# Batchwise Total loss :  3.790694236755371
# step_num :  83
# Average training loss :  0.9765202403068542
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7709693908691406
# Batchwise Total loss :  3.7474896907806396
# step_num :  84
# Average training loss :  1.1076488494873047
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7527453899383545
# Batchwise Total loss :  3.860394239425659
# step_num :  85
# Average training loss :  1.0894134044647217
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.750703811645508
# Batchwise Total loss :  3.8401172161102295
# step_num :  86
# Average training loss :  0.9570094347000122
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7871901988983154
# Batchwise Total loss :  3.744199752807617
# step_num :  87
# Average training loss :  1.0091731548309326
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7748420238494873
# Batchwise Total loss :  3.78401517868042
# step_num :  88
# Average training loss :  1.1132005453109741
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7713675498962402
# Batchwise Total loss :  3.884568214416504
# step_num :  89
# Average training loss :  0.8738692402839661
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.77593731880188
# Batchwise Total loss :  3.649806499481201
# step_num :  90
# Average training loss :  0.961495041847229
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7568373680114746
# Batchwise Total loss :  3.718332290649414
# step_num :  91
# Average training loss :  1.0994973182678223
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7517929077148438
# Batchwise Total loss :  3.851290225982666
# step_num :  92
# Average training loss :  1.0338634252548218
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7601425647735596
# Batchwise Total loss :  3.794005870819092
# step_num :  93
# Average training loss :  0.922519862651825
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7406508922576904
# Batchwise Total loss :  3.66317081451416
# step_num :  94
# Average training loss :  0.8567296862602234
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.762145519256592
# Batchwise Total loss :  3.61887526512146
# step_num :  95
# Average training loss :  1.0691934823989868
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.749134063720703
# Batchwise Total loss :  3.8183274269104004
# step_num :  96
# Average training loss :  0.8891278505325317
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.739163875579834
# Batchwise Total loss :  3.628291606903076
# step_num :  97
# Average training loss :  0.8421611785888672
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.754714250564575
# Batchwise Total loss :  3.5968754291534424
# step_num :  98
# Average training loss :  0.9242542386054993
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7358522415161133
# Batchwise Total loss :  3.6601064205169678
# step_num :  99
# Average training loss :  0.9057458639144897
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7538347244262695
# Batchwise Total loss :  3.659580707550049
# step_num :  100
# Average training loss :  0.9778887033462524
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.73392653465271
# Batchwise Total loss :  3.711815357208252
# step_num :  101
# Average training loss :  0.9268722534179688
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7229936122894287
# Batchwise Total loss :  3.6498658657073975
# step_num :  102
# Average training loss :  1.0383554697036743
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7368454933166504
# Batchwise Total loss :  3.775200843811035
# step_num :  103
# Average training loss :  0.7689924836158752
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.738935947418213
# Batchwise Total loss :  3.5079283714294434
# step_num :  104
# Average training loss :  0.7396659851074219
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.754952907562256
# Batchwise Total loss :  3.4946188926696777
# step_num :  105
# Average training loss :  0.8509639501571655
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.743377685546875
# Batchwise Total loss :  3.59434175491333
# step_num :  106
# Average training loss :  0.9003428220748901
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7369632720947266
# Batchwise Total loss :  3.6373062133789062
# step_num :  107
# Average training loss :  0.8885122537612915
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.724299430847168
# Batchwise Total loss :  3.61281156539917
# step_num :  108
# Average training loss :  0.9174788594245911
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7245049476623535
# Batchwise Total loss :  3.6419837474823
# step_num :  109
# Average training loss :  0.9030624628067017
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.735069751739502
# Batchwise Total loss :  3.638132095336914
# step_num :  110
# Average training loss :  0.8815227746963501
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.747605085372925
# Batchwise Total loss :  3.6291279792785645
# step_num :  111
# Average training loss :  0.7890650629997253
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7491211891174316
# Batchwise Total loss :  3.5381863117218018
# step_num :  112
# Average training loss :  0.9091035723686218
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7347891330718994
# Batchwise Total loss :  3.643892765045166
# step_num :  113
# Average training loss :  0.9155498743057251
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7455246448516846
# Batchwise Total loss :  3.661074638366699
# step_num :  114
# Average training loss :  0.7893840670585632
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7312402725219727
# Batchwise Total loss :  3.5206243991851807
# step_num :  115
# Average training loss :  0.9876360893249512
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7316105365753174
# Batchwise Total loss :  3.7192466259002686
# step_num :  116
# Average training loss :  0.9237531423568726
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7582411766052246
# Batchwise Total loss :  3.6819944381713867
# step_num :  117
# Average training loss :  0.7911368012428284
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.734764814376831
# Batchwise Total loss :  3.5259015560150146
# step_num :  118
# Average training loss :  0.7893160581588745
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.740727663040161
# Batchwise Total loss :  3.530043601989746
# step_num :  119
# Average training loss :  0.9548575282096863
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7279775142669678
# Batchwise Total loss :  3.682835102081299
# step_num :  120
# Average training loss :  0.8681808710098267
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.744762659072876
# Batchwise Total loss :  3.612943649291992
# step_num :  121
# Average training loss :  0.964227020740509
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7012174129486084
# Batchwise Total loss :  3.6654443740844727
# step_num :  122
# Average training loss :  0.7296572923660278
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.719860076904297
# Batchwise Total loss :  3.449517250061035
# step_num :  123
# Average training loss :  0.8239885568618774
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7621169090270996
# Batchwise Total loss :  3.5861053466796875
# step_num :  124
# Average training loss :  1.0071990489959717
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7113893032073975
# Batchwise Total loss :  3.718588352203369
# step_num :  125
# Average training loss :  0.8059229850769043
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7699272632598877
# Batchwise Total loss :  3.575850248336792
# step_num :  126
# Average training loss :  0.7953975200653076
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.740265130996704
# Batchwise Total loss :  3.5356626510620117
# step_num :  127
# Average training loss :  0.8171765208244324
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7445478439331055
# Batchwise Total loss :  3.5617244243621826
# step_num :  128
# Average training loss :  0.8431209325790405
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7592506408691406
# Batchwise Total loss :  3.6023716926574707
# step_num :  129
# Average training loss :  0.8437888026237488
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.743732452392578
# Batchwise Total loss :  3.5875213146209717
# step_num :  130
# Average training loss :  0.9097194671630859
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7395527362823486
# Batchwise Total loss :  3.6492722034454346
# step_num :  131
# Average training loss :  0.8731317520141602
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7447147369384766
# Batchwise Total loss :  3.6178464889526367
# step_num :  132
# Average training loss :  0.8204693794250488
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.744515895843506
# Batchwise Total loss :  3.5649852752685547
# step_num :  133
# Average training loss :  0.8088332414627075
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7317311763763428
# Batchwise Total loss :  3.54056453704834
# step_num :  134
# Average training loss :  0.7270618677139282
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7493832111358643
# Batchwise Total loss :  3.476445198059082
# step_num :  135
# Average training loss :  0.691277801990509
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7439534664154053
# Batchwise Total loss :  3.4352312088012695
# step_num :  136
# Average training loss :  0.896966814994812
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7272756099700928
# Batchwise Total loss :  3.6242423057556152
# step_num :  137
# Average training loss :  0.856643795967102
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.724709987640381
# Batchwise Total loss :  3.5813536643981934
# step_num :  138
# Average training loss :  0.7461227178573608
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.734755516052246
# Batchwise Total loss :  3.4808783531188965
# step_num :  139
# Average training loss :  0.7458196878433228
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7469799518585205
# Batchwise Total loss :  3.492799758911133
# step_num :  140
# Average training loss :  0.8358874320983887
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.736363649368286
# Batchwise Total loss :  3.572251081466675
# step_num :  141
# Average training loss :  0.7386635541915894
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7237775325775146
# Batchwise Total loss :  3.4624409675598145
# step_num :  142
# Average training loss :  0.7989367246627808
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.738994836807251
# Batchwise Total loss :  3.537931442260742
# step_num :  143
# Average training loss :  0.6484476327896118
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7074408531188965
# Batchwise Total loss :  3.3558883666992188
# step_num :  144
# Average training loss :  0.7986283302307129
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6999332904815674
# Batchwise Total loss :  3.4985616207122803
# step_num :  145
# Average training loss :  0.7343499064445496
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.744462728500366
# Batchwise Total loss :  3.4788126945495605
# step_num :  146
# Average training loss :  0.8768888711929321
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7271504402160645
# Batchwise Total loss :  3.604039192199707
# step_num :  147
# Average training loss :  0.8201851844787598
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.73353910446167
# Batchwise Total loss :  3.5537242889404297
# step_num :  148
# Average training loss :  0.8046444058418274
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.716120719909668
# Batchwise Total loss :  3.5207650661468506
# step_num :  149
# Average training loss :  0.8159395456314087
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7033121585845947
# Batchwise Total loss :  3.519251823425293
# step_num :  150
# Average training loss :  0.7210288047790527
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6790003776550293
# Batchwise Total loss :  3.400029182434082
# step_num :  151
# Average training loss :  0.8969401121139526
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6625146865844727
# Batchwise Total loss :  3.559454917907715
# step_num :  152
# Average training loss :  0.8052099943161011
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.671926498413086
# Batchwise Total loss :  3.4771366119384766
# step_num :  153
# Average training loss :  0.8149229884147644
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.69557523727417
# Batchwise Total loss :  3.510498285293579
# step_num :  154
# Average training loss :  0.8235635757446289
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6792306900024414
# Batchwise Total loss :  3.5027942657470703
# step_num :  155
# Average training loss :  0.8088165521621704
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.657177209854126
# Batchwise Total loss :  3.465993881225586
# step_num :  156
# Average training loss :  0.8112643361091614
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6386938095092773
# Batchwise Total loss :  3.449958086013794
# step_num :  157
# Average training loss :  0.8610633015632629
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6347644329071045
# Batchwise Total loss :  3.4958276748657227
# step_num :  158
# Average training loss :  0.8466523289680481
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.684602737426758
# Batchwise Total loss :  3.531255006790161
# step_num :  159
# Average training loss :  0.892970085144043
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6380186080932617
# Batchwise Total loss :  3.5309886932373047
# step_num :  160
# Average training loss :  0.819595217704773
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6371910572052
# Batchwise Total loss :  3.4567861557006836
# step_num :  161
# Average training loss :  0.9248998761177063
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.649435043334961
# Batchwise Total loss :  3.5743348598480225
# step_num :  162
# Average training loss :  0.8682225942611694
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.650663137435913
# Batchwise Total loss :  3.518885612487793
# step_num :  163
# Average training loss :  0.8028298616409302
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6556363105773926
# Batchwise Total loss :  3.458466053009033
# step_num :  164
# Average training loss :  0.838858425617218
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6762185096740723
# Batchwise Total loss :  3.5150768756866455
# step_num :  165
# Average training loss :  0.8929871320724487
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6627871990203857
# Batchwise Total loss :  3.555774211883545
# step_num :  166
# Average training loss :  0.9341439008712769
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.666351795196533
# Batchwise Total loss :  3.6004958152770996
# step_num :  167
# Average training loss :  0.8704004287719727
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6507019996643066
# Batchwise Total loss :  3.5211024284362793
# step_num :  168
# Average training loss :  0.85350102186203
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.659780502319336
# Batchwise Total loss :  3.5132815837860107
# step_num :  169
# Average training loss :  0.8863505125045776
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6636343002319336
# Batchwise Total loss :  3.549984931945801
# step_num :  170
# Average training loss :  0.9196828007698059
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.666374683380127
# Batchwise Total loss :  3.586057424545288
# step_num :  171
# Average training loss :  0.7299161553382874
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6514999866485596
# Batchwise Total loss :  3.381416082382202
# step_num :  172
# Average training loss :  0.8852077722549438
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.66498064994812
# Batchwise Total loss :  3.5501885414123535
# step_num :  173
# Average training loss :  0.8204187154769897
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6802289485931396
# Batchwise Total loss :  3.50064754486084
# step_num :  174
# Average training loss :  0.8308008909225464
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.686741590499878
# Batchwise Total loss :  3.5175423622131348
# step_num :  175
# Average training loss :  0.8811531066894531
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6875269412994385
# Batchwise Total loss :  3.5686800479888916
# step_num :  176
# Average training loss :  0.9048395156860352
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.698776960372925
# Batchwise Total loss :  3.60361647605896
# step_num :  177
# Average training loss :  0.724327802658081
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.683575391769409
# Batchwise Total loss :  3.4079031944274902
# step_num :  178
# Average training loss :  0.8542617559432983
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6960408687591553
# Batchwise Total loss :  3.550302505493164
# step_num :  179
# Average training loss :  0.8816168904304504
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6759064197540283
# Batchwise Total loss :  3.557523250579834
# step_num :  180
# Average training loss :  0.8040043711662292
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.693227767944336
# Batchwise Total loss :  3.49723219871521
# step_num :  181
# Average training loss :  0.9022285342216492
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.686138153076172
# Batchwise Total loss :  3.588366746902466
# step_num :  182
# Average training loss :  0.7620940208435059
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6976003646850586
# Batchwise Total loss :  3.4596943855285645
# step_num :  183
# Average training loss :  0.8640336990356445
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.694883108139038
# Batchwise Total loss :  3.5589168071746826
# step_num :  184
# Average training loss :  0.7513501048088074
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6885733604431152
# Batchwise Total loss :  3.4399235248565674
# step_num :  185
# Average training loss :  0.750237762928009
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.691131353378296
# Batchwise Total loss :  3.44136905670166
# step_num :  186
# Average training loss :  0.83924400806427
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.679612874984741
# Batchwise Total loss :  3.518857002258301
# step_num :  187
# Average training loss :  0.7911334037780762
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7030508518218994
# Batchwise Total loss :  3.4941842555999756
# step_num :  188
# Average training loss :  0.8186361193656921
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.688448667526245
# Batchwise Total loss :  3.507084846496582
# step_num :  189
# Average training loss :  0.8779447674751282
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6880111694335938
# Batchwise Total loss :  3.565955877304077
# step_num :  190
# Average training loss :  0.668103814125061
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7015695571899414
# Batchwise Total loss :  3.369673252105713
# step_num :  191
# Average training loss :  0.8796820640563965
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6815640926361084
# Batchwise Total loss :  3.561246156692505
# step_num :  192
# Average training loss :  0.8050718307495117
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6910414695739746
# Batchwise Total loss :  3.4961133003234863
# step_num :  193
# Average training loss :  0.8120419383049011
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7031216621398926
# Batchwise Total loss :  3.5151636600494385
# step_num :  194
# Average training loss :  0.7731810808181763
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.694960594177246
# Batchwise Total loss :  3.468141555786133
# step_num :  195
# Average training loss :  0.9075131416320801
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6956939697265625
# Batchwise Total loss :  3.6032071113586426
# step_num :  196
# Average training loss :  0.8571521639823914
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6942052841186523
# Batchwise Total loss :  3.5513575077056885
# step_num :  197
# Average training loss :  0.8872232437133789
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7062816619873047
# Batchwise Total loss :  3.5935049057006836
# step_num :  198
# Average training loss :  0.9646832346916199
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.667757987976074
# Batchwise Total loss :  3.632441282272339
# step_num :  199
# Average training loss :  0.8837518692016602
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7043049335479736
# Batchwise Total loss :  3.588056802749634
# step_num :  200
# Average training loss :  0.8229773640632629
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.682983160018921
# Batchwise Total loss :  3.505960464477539
# step_num :  201
# Average training loss :  0.797977864742279
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7222869396209717
# Batchwise Total loss :  3.5202648639678955
# step_num :  202
# Average training loss :  0.6915614008903503
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.71040940284729
# Batchwise Total loss :  3.401970863342285
# step_num :  203
# Average training loss :  0.8068572878837585
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.6866047382354736
# Batchwise Total loss :  3.493462085723877
# step_num :  204
# Average training loss :  0.8070151209831238
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.700676202774048
# Batchwise Total loss :  3.5076913833618164
# step_num :  205
# Average training loss :  0.8472309112548828
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7037200927734375
# Batchwise Total loss :  3.5509510040283203
# step_num :  206
# Average training loss :  0.8248584866523743
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7102949619293213
# Batchwise Total loss :  3.535153388977051
# step_num :  207
# Average training loss :  0.936832070350647
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7098324298858643
# Batchwise Total loss :  3.646664619445801
# step_num :  208
# Average training loss :  0.8772556185722351
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.699408531188965
# Batchwise Total loss :  3.5766642093658447
# step_num :  209
# Average training loss :  0.8862627744674683
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.700502872467041
# Batchwise Total loss :  3.586765766143799
# step_num :  210
# Average training loss :  0.8624898195266724
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.714365243911743
# Batchwise Total loss :  3.576855182647705
# step_num :  211
# Average training loss :  0.8786265254020691
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.722611427307129
# Batchwise Total loss :  3.6012380123138428
# step_num :  212
# Average training loss :  0.7873955965042114
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7167983055114746
# Batchwise Total loss :  3.5041937828063965
# step_num :  213
# Average training loss :  0.7519872784614563
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.721196413040161
# Batchwise Total loss :  3.4731836318969727
# step_num :  214
# Average training loss :  0.8131429553031921
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.737103223800659
# Batchwise Total loss :  3.550246238708496
# step_num :  215
# Average training loss :  0.7690484523773193
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7137651443481445
# Batchwise Total loss :  3.482813596725464
# step_num :  216
# Average training loss :  0.7749118208885193
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7326016426086426
# Batchwise Total loss :  3.5075135231018066
# step_num :  217
# Average training loss :  0.8002912402153015
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7400851249694824
# Batchwise Total loss :  3.5403764247894287
# step_num :  218
# Average training loss :  0.8353720903396606
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7404959201812744
# Batchwise Total loss :  3.5758681297302246
# step_num :  219
# Average training loss :  0.8282844424247742
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7552783489227295
# Batchwise Total loss :  3.5835628509521484
# step_num :  220
# Average training loss :  0.9050129055976868
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7377302646636963
# Batchwise Total loss :  3.6427431106567383
# step_num :  221
# Average training loss :  0.8630167841911316
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.726811170578003
# Batchwise Total loss :  3.5898280143737793
# step_num :  222
# Average training loss :  0.8888247609138489
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7186946868896484
# Batchwise Total loss :  3.6075193881988525
# step_num :  223
# Average training loss :  0.8792206048965454
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7536518573760986
# Batchwise Total loss :  3.6328725814819336
# step_num :  224
# Average training loss :  0.6804364919662476
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7558000087738037
# Batchwise Total loss :  3.4362363815307617
# step_num :  225
# Average training loss :  0.7301520705223083
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7342872619628906
# Batchwise Total loss :  3.4644393920898438
# step_num :  226
# Average training loss :  0.9282335042953491
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.751150608062744
# Batchwise Total loss :  3.679384231567383
# step_num :  227
# Average training loss :  0.7715397477149963
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7373769283294678
# Batchwise Total loss :  3.5089166164398193
# step_num :  228
# Average training loss :  0.8785269856452942
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7411723136901855
# Batchwise Total loss :  3.619699239730835
# step_num :  229
# Average training loss :  0.8833775520324707
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.746213436126709
# Batchwise Total loss :  3.6295909881591797
# step_num :  230
# Average training loss :  0.7877560257911682
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.730902671813965
# Batchwise Total loss :  3.5186586380004883
# step_num :  231
# Average training loss :  0.7803283929824829
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7433834075927734
# Batchwise Total loss :  3.523711681365967
# step_num :  232
# Average training loss :  0.8465682864189148
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.747298240661621
# Batchwise Total loss :  3.5938665866851807
# step_num :  233
# Average training loss :  0.8421347737312317
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7569077014923096
# Batchwise Total loss :  3.5990424156188965
# step_num :  234
# Average training loss :  0.7519800662994385
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7346651554107666
# Batchwise Total loss :  3.486645221710205
# step_num :  235
# Average training loss :  0.8277831077575684
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7437353134155273
# Batchwise Total loss :  3.5715184211730957
# step_num :  236
# Average training loss :  0.8918774724006653
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7423906326293945
# Batchwise Total loss :  3.634268045425415
# step_num :  237
# Average training loss :  0.8136933445930481
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.731797695159912
# Batchwise Total loss :  3.5454909801483154
# step_num :  238
# Average training loss :  0.8483737707138062
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.765446901321411
# Batchwise Total loss :  3.6138205528259277
# step_num :  239
# Average training loss :  0.7993059158325195
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7439441680908203
# Batchwise Total loss :  3.54325008392334
# step_num :  240
# Average training loss :  0.8705011606216431
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.738459348678589
# Batchwise Total loss :  3.6089606285095215
# step_num :  241
# Average training loss :  0.9510606527328491
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.751345157623291
# Batchwise Total loss :  3.7024059295654297
# step_num :  242
# Average training loss :  0.7315880656242371
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7469582557678223
# Batchwise Total loss :  3.478546380996704
# step_num :  243
# Average training loss :  0.6834880709648132
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.748443365097046
# Batchwise Total loss :  3.431931495666504
# step_num :  244
# Average training loss :  0.842501163482666
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.738434314727783
# Batchwise Total loss :  3.580935478210449
# step_num :  245
# Average training loss :  0.9204031229019165
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7518818378448486
# Batchwise Total loss :  3.6722850799560547
# step_num :  246
# Average training loss :  0.8600886464118958
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.75227689743042
# Batchwise Total loss :  3.612365484237671
# step_num :  247
# Average training loss :  0.7237909436225891
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7505364418029785
# Batchwise Total loss :  3.474327325820923
# step_num :  248
# Average training loss :  0.8580859899520874
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.730579137802124
# Batchwise Total loss :  3.588665008544922
# step_num :  249
# Average training loss :  1.005216360092163
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7311112880706787
# Batchwise Total loss :  3.736327648162842
# step_num :  250
# Average training loss :  0.8373937606811523
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7401905059814453
# Batchwise Total loss :  3.5775842666625977
# step_num :  251
# Average training loss :  0.7530568838119507
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.706707000732422
# Batchwise Total loss :  3.459764003753662
# step_num :  252
# Average training loss :  0.8643518686294556
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7555055618286133
# Batchwise Total loss :  3.6198573112487793
# step_num :  253
# Average training loss :  0.7976831197738647
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.728205442428589
# Batchwise Total loss :  3.525888442993164
# step_num :  254
# Average training loss :  0.710236668586731
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.724161386489868
# Batchwise Total loss :  3.4343981742858887
# step_num :  255
# Average training loss :  0.6723361611366272
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.728508472442627
# Batchwise Total loss :  3.4008445739746094
# step_num :  256
# Average training loss :  0.7387534379959106
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7262747287750244
# Batchwise Total loss :  3.4650282859802246
# step_num :  257
# Average training loss :  0.7518620491027832
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7364723682403564
# Batchwise Total loss :  3.4883344173431396
# step_num :  258
# Average training loss :  0.7018755674362183
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.734607458114624
# Batchwise Total loss :  3.4364829063415527
# step_num :  259
# Average training loss :  0.8264412879943848
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.742788314819336
# Batchwise Total loss :  3.5692296028137207
# step_num :  260
# Average training loss :  0.7670825719833374
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7513277530670166
# Batchwise Total loss :  3.5184102058410645
# step_num :  261
# Average training loss :  0.7371150255203247
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.731128454208374
# Batchwise Total loss :  3.4682435989379883
# step_num :  262
# Average training loss :  0.6633381843566895
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7292606830596924
# Batchwise Total loss :  3.392598867416382
# step_num :  263
# Average training loss :  0.770695686340332
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7558300495147705
# Batchwise Total loss :  3.5265257358551025
# step_num :  264
# Average training loss :  0.7656947374343872
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.73258113861084
# ...
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7462449073791504
# Batchwise Total loss :  3.2415874004364014
# step_num :  314
# Average training loss :  0.581271767616272
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.711164951324463
# Batchwise Total loss :  3.2924365997314453
# step_num :  315
# Average training loss :  0.574851393699646
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7536957263946533
# Batchwise Total loss :  3.3285470008850098
# step_num :  316
# Average training loss :  0.4409399926662445
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7197179794311523
# Batchwise Total loss :  3.1606578826904297
# step_num :  317
# Average training loss :  0.5128296613693237
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.746608257293701
# Batchwise Total loss :  3.2594380378723145
# step_num :  318
# Average training loss :  0.5338473916053772
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7284038066864014
# Batchwise Total loss :  3.262251138687134
# step_num :  319
# Average training loss :  0.5076525211334229
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.733830451965332
# Batchwise Total loss :  3.241482973098755
# step_num :  320
# Average training loss :  0.4666978716850281
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.740962028503418
# Batchwise Total loss :  3.207659959793091
# step_num :  321
# Average training loss :  0.48971062898635864
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7143917083740234
# Batchwise Total loss :  3.2041022777557373
# step_num :  322
# Average training loss :  0.5348909497261047
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.724940538406372
# Batchwise Total loss :  3.259831428527832
# step_num :  323
# Average training loss :  0.6232126355171204
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.734123468399048
# Batchwise Total loss :  3.3573360443115234
# step_num :  324
# Average training loss :  0.48954835534095764
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7142446041107178
# Batchwise Total loss :  3.2037930488586426
# step_num :  325
# Average training loss :  0.6034446954727173
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.732421875
# Batchwise Total loss :  3.3358664512634277
# step_num :  326
# Average training loss :  0.5479159355163574
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7471721172332764
# Batchwise Total loss :  3.295088052749634
# step_num :  327
# Average training loss :  0.5782294273376465
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.75538969039917
# Batchwise Total loss :  3.3336191177368164
# step_num :  328
# Average training loss :  0.5582752823829651
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7075510025024414
# Batchwise Total loss :  3.2658262252807617
# step_num :  329
# Average training loss :  0.5585681796073914
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7467410564422607
# Batchwise Total loss :  3.305309295654297
# step_num :  330
# Average training loss :  0.5322288274765015
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7282097339630127
# Batchwise Total loss :  3.2604384422302246
# step_num :  331
# Average training loss :  0.5719975829124451
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.721679925918579
# Batchwise Total loss :  3.293677568435669
# step_num :  332
# Average training loss :  0.5338454842567444
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7257297039031982
# Batchwise Total loss :  3.259575128555298
# step_num :  333
# Average training loss :  0.568087100982666
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7472033500671387
# Batchwise Total loss :  3.3152904510498047
# step_num :  334
# Average training loss :  0.6206384897232056
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7407565116882324
# Batchwise Total loss :  3.3613948822021484
# step_num :  335
# Average training loss :  0.600617527961731
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.721090078353882
# Batchwise Total loss :  3.3217077255249023
# step_num :  336
# Average training loss :  0.4700113832950592
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.696349620819092
# Batchwise Total loss :  3.166361093521118
# step_num :  337
# Average training loss :  0.4578487277030945
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7534656524658203
# Batchwise Total loss :  3.2113144397735596
# step_num :  338
# Average training loss :  0.549000084400177
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.715442180633545
# Batchwise Total loss :  3.264442205429077
# step_num :  339
# Average training loss :  0.4881598949432373
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.725351572036743
# Batchwise Total loss :  3.2135114669799805
# step_num :  340
# Average training loss :  0.5690934062004089
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7442104816436768
# Batchwise Total loss :  3.3133039474487305
# step_num :  341
# Average training loss :  0.5289551019668579
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.718231439590454
# Batchwise Total loss :  3.2471866607666016
# step_num :  342
# Average training loss :  0.5404068231582642
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7052531242370605
# Batchwise Total loss :  3.245659828186035
# step_num :  343
# Average training loss :  0.6437157392501831
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7261061668395996
# Batchwise Total loss :  3.3698220252990723
# step_num :  344
# Average training loss :  0.5177309513092041
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.729614496231079
# Batchwise Total loss :  3.247345447540283
# step_num :  345
# Average training loss :  0.5214626789093018
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7439794540405273
# Batchwise Total loss :  3.265442132949829
# step_num :  346
# Average training loss :  0.5872519016265869
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7367570400238037
# Batchwise Total loss :  3.3240089416503906
# step_num :  347
# Average training loss :  0.5538948774337769
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.701704502105713
# Batchwise Total loss :  3.2555994987487793
# step_num :  348
# Average training loss :  0.5863100290298462
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.732494354248047
# Batchwise Total loss :  3.3188042640686035
# step_num :  349
# Average training loss :  0.4584549367427826
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7517635822296143
# Batchwise Total loss :  3.2102184295654297
# step_num :  350
# Average training loss :  0.6806057691574097
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.730391502380371
# Batchwise Total loss :  3.4109973907470703
# step_num :  351
# Average training loss :  0.5439126491546631
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.725647211074829
# Batchwise Total loss :  3.269559860229492
# step_num :  352
# Average training loss :  0.5250896215438843
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.743183135986328
# Batchwise Total loss :  3.268272876739502
# step_num :  353
# Average training loss :  0.5557178258895874
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7099616527557373
# Batchwise Total loss :  3.265679359436035
# step_num :  354
# Average training loss :  0.5658751726150513
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.740227699279785
# Batchwise Total loss :  3.306102752685547
# step_num :  355
# Average training loss :  0.6249200105667114
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7218151092529297
# Batchwise Total loss :  3.3467350006103516
# step_num :  356
# Average training loss :  0.5070589780807495
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.701169729232788
# Batchwise Total loss :  3.208228588104248
# step_num :  357
# Average training loss :  0.5165696740150452
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7315309047698975
# Batchwise Total loss :  3.248100519180298
# step_num :  358
# Average training loss :  0.616063117980957
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.74605655670166
# Batchwise Total loss :  3.362119674682617
# step_num :  359
# Average training loss :  0.5525461435317993
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.741931915283203
# Batchwise Total loss :  3.294477939605713
# step_num :  360
# Average training loss :  0.47547879815101624
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7283289432525635
# Batchwise Total loss :  3.203807830810547
# step_num :  361
# Average training loss :  0.5289732217788696
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7128865718841553
# Batchwise Total loss :  3.2418599128723145
# step_num :  362
# Average training loss :  0.5307382941246033
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7398464679718018
# Batchwise Total loss :  3.27058482170105
# step_num :  363
# Average training loss :  0.4677838683128357
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.729686737060547
# Batchwise Total loss :  3.1974706649780273
# step_num :  364
# Average training loss :  0.5598248243331909
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7128238677978516
# Batchwise Total loss :  3.272648811340332
# step_num :  365
# Average training loss :  0.47581690549850464
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7450034618377686
# Batchwise Total loss :  3.220820426940918
# step_num :  366
# Average training loss :  0.4993080496788025
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7314772605895996
# Batchwise Total loss :  3.230785369873047
# step_num :  367
# Average training loss :  0.6194248199462891
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7675740718841553
# Batchwise Total loss :  3.3869988918304443
# step_num :  368
# Average training loss :  0.5301022529602051
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7353265285491943
# Batchwise Total loss :  3.2654287815093994
# step_num :  369
# Average training loss :  0.5853267908096313
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7412068843841553
# Batchwise Total loss :  3.326533794403076
# step_num :  370
# Average training loss :  0.5538930296897888
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7279789447784424
# Batchwise Total loss :  3.281872034072876
# step_num :  371
# Average training loss :  0.5929804444313049
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.715735912322998
# Batchwise Total loss :  3.308716297149658
# step_num :  372
# Average training loss :  0.6304611563682556
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.72993540763855
# Batchwise Total loss :  3.36039662361145
# step_num :  373
# Average training loss :  0.4563773274421692
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.72782301902771
# Batchwise Total loss :  3.1842002868652344
# step_num :  374
# Average training loss :  0.501606822013855
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.724987030029297
# Batchwise Total loss :  3.2265939712524414
# step_num :  375
# Average training loss :  0.5805272459983826
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7410359382629395
# Batchwise Total loss :  3.321563243865967
# step_num :  376
# Average training loss :  0.5451108813285828
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7171034812927246
# Batchwise Total loss :  3.262214422225952
# step_num :  377
# Average training loss :  0.44617971777915955
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.72314715385437
# Batchwise Total loss :  3.1693267822265625
# step_num :  378
# Average training loss :  0.57451331615448
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.718604326248169
# Batchwise Total loss :  3.2931175231933594
# step_num :  379
# Average training loss :  0.5115860104560852
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.71720027923584
# Batchwise Total loss :  3.2287862300872803
# step_num :  380
# Average training loss :  0.45040765404701233
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.718736171722412
# Batchwise Total loss :  3.1691439151763916
# step_num :  381
# Average training loss :  0.4376072287559509
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7327332496643066
# Batchwise Total loss :  3.1703405380249023
# step_num :  382
# Average training loss :  0.6047877073287964
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7072134017944336
# Batchwise Total loss :  3.3120012283325195
# step_num :  383
# Average training loss :  0.5372105836868286
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.729969024658203
# Batchwise Total loss :  3.267179489135742
# step_num :  384
# Average training loss :  0.4368169903755188
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.721630096435547
# Batchwise Total loss :  3.158447027206421
# step_num :  385
# Average training loss :  0.5491863489151001
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7306833267211914
# Batchwise Total loss :  3.279869556427002
# step_num :  386
# Average training loss :  0.590516984462738
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.714369773864746
# Batchwise Total loss :  3.304886817932129
# step_num :  387
# Average training loss :  0.6037840843200684
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.756124973297119
# Batchwise Total loss :  3.3599090576171875
# step_num :  388
# Average training loss :  0.5599721670150757
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.739684581756592
# Batchwise Total loss :  3.299656867980957
# step_num :  389
# Average training loss :  0.5283443331718445
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.702178478240967
# Batchwise Total loss :  3.230522871017456
# step_num :  390
# Average training loss :  0.44988054037094116
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.735002279281616
# Batchwise Total loss :  3.184882879257202
# step_num :  391
# Average training loss :  0.5787343978881836
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7237625122070312
# Batchwise Total loss :  3.302496910095215
# step_num :  392
# Average training loss :  0.5250179767608643
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.726903200149536
# Batchwise Total loss :  3.2519211769104004
# step_num :  393
# Average training loss :  0.5267994999885559
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7220377922058105
# Batchwise Total loss :  3.2488372325897217
# step_num :  394
# Average training loss :  0.6035352945327759
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7186005115509033
# Batchwise Total loss :  3.3221359252929688
# step_num :  395
# Average training loss :  0.5508637428283691
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7376549243927
# Batchwise Total loss :  3.2885186672210693
# step_num :  396
# Average training loss :  0.5987096428871155
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7489097118377686
# Batchwise Total loss :  3.3476192951202393
# step_num :  397
# Average training loss :  0.49076324701309204
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7350738048553467
# Batchwise Total loss :  3.225836992263794
# step_num :  398
# Average training loss :  0.41735607385635376
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.721526622772217
# Batchwise Total loss :  3.138882637023926
# step_num :  399
# Average training loss :  0.5540286302566528
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  2.7335667610168457
# Batchwise Total loss :  3.287595272064209
# step_num :  400
# Average training loss :  0.5537462830543518
# Computing 1D 1-wasserstein distance.
# Batchwise Topo loss :  1.629482626914978
# Batchwise Total loss :  2.1832289695739746
# 100%|███████████████████████████████████████████████████████████████████████████████| 30/30 [3:15:14<00:00, 390.49s/it]
